# %%
import nl4py
import pandas as pd
import numpy as np

#Start the NetLogoControllerServer
nl4py.startServer("C:/Program Files/NetLogo 6.0.3")

def simulate(workspace_,parameters):
    workspace_.command("stop")
    for i, name in enumerate(problem['names']):
        if name == 'random-seed':
            workspace_.command('random-seed {}'.format(parameters[i]))
        else:
            workspace_.command('set {0} {1}'.format(name, parameters[i]))
    workspace_.command('set model-version "sheep-wolves-grass"')
    workspace_.command('setup')
    workspace_.scheduleReportersAndRun(["ticks",'count sheep','count wolves'], 0,1,100,"go")
# Out:
# Server started.

# %%
def runForParameters(experiment):
    runsDone = 0
    runsStarted = 0
    runsNeeded = experiment.shape[0]
    sheep_to_wolves_ratios = []
    #Find the number of cores on this machine so we can create the optimal number of parallel workspaces
    import multiprocessing
    parallel_workspace_count = multiprocessing.cpu_count()
    for i in range(0,parallel_workspace_count):
        workspace = nl4py.newNetLogoHeadlessWorkspace()
        workspace.openModel('Wolf Sheep Predation.nlogo')
        simulate(workspace,experiment[runsStarted])
        runsStarted = runsStarted + 1
    while (runsDone < runsNeeded):
        for workspace in nl4py.getAllHeadlessWorkspaces():
            newResults = workspace.getScheduledReporterResults()
            if len(newResults) > 0:
                df = pd.DataFrame(newResults)
                sheep_to_wolves_ratio = pd.to_numeric(df.iloc[:,1]).div(0.00001 + pd.to_numeric(df.iloc[:,2]))
                sheep_to_wolves_ratio = sheep_to_wolves_ratio.sum()/len(newResults)
                sheep_to_wolves_ratios.append(sheep_to_wolves_ratio)
                runsDone = runsDone + 1
                if runsStarted < runsNeeded:
                    simulate(workspace,experiment[runsStarted])
                    runsStarted = runsStarted + 1
    for workspace in nl4py.getAllHeadlessWorkspaces():
        workspace.command("stop")
    nl4py.deleteAllHeadlessWorkspaces()
    
    return sheep_to_wolves_ratios

# %%
ws = nl4py.newNetLogoHeadlessWorkspace()
ws.openModel("./Wolf Sheep Predation.nlogo")
#Read in the parameter info with NL4Py functions and generate a SALib problem
problem = { 
  'num_vars': 8,
  'names': ['random-seed'],
  'bounds': [[1, 100000]]
}
problem['names'].extend(ws.getParamNames()[:-2])
problem['bounds'].extend( [item[0::2] for item in ws.getParamRanges()[:-2]])
print(problem)
# Out:
# {'bounds': [[1, 100000], [0.0, 250.0], [0.0, 50.0], [1.0, 20.0], [0.0, 250.0], [0.0, 100.0], [0.0, 20.0], [0.0, 100.0]], 'num_vars': 8, 'names': ['random-seed', u'initial-number-sheep', u'sheep-gain-from-food', u'sheep-reproduce', u'initial-number-wolves', u'wolf-gain-from-food', u'wolf-reproduce', u'grass-regrowth-time']}

# %%
from SALib.sample import saltelli
from SALib.analyze import sobol
# Generate samples
param_values_sobol = saltelli.sample(problem, 1000)
#print(param_values)
# Run the "model" and save the output in a text file
# This will happen offline for external models
Y = np.array(runForParameters(param_values_sobol))
#print(Y)
#print(Y.var())
# Perform the sensitivity analysis using the model output
# Specify which column of the output file to analyze (zero-indexed)
Si_Sobol = sobol.analyze(problem, Y, print_to_console=True)
# Returns a dictionary with keys 'S1' and 'ST'
# e.g. Si['S1'] contains the first-order index for each parameter, in the
# same order as the parameter file
# Out:
# total variance:
# 1.0000000000000002
# normalized by:
# 1.1616969036881803
# Parameter S1 S1_conf ST ST_conf
# random-seed -0.001475 0.005188 0.050121 0.176022
# initial-number-sheep 0.001781 0.012766 0.162393 0.288743
# sheep-gain-from-food 0.006923 0.016481 0.120741 0.067295
# sheep-reproduce -0.001011 0.009495 0.233478 0.403904
# initial-number-wolves 0.010562 0.033568 0.034290 0.076085
# wolf-gain-from-food 0.116207 0.252794 1.216336 1.255876
# wolf-reproduce -0.001368 0.005216 0.119809 0.241017
# grass-regrowth-time 0.000385 0.013991 0.767028 0.537522
#
# Parameter_1 Parameter_2 S2 S2_conf
# random-seed initial-number-sheep 0.002224 0.006003
# random-seed sheep-gain-from-food 0.001923 0.005812
# random-seed sheep-reproduce 0.002026 0.005740
# random-seed initial-number-wolves 0.002484 0.005858
# random-seed wolf-gain-from-food 0.000155 0.007194
# random-seed wolf-reproduce 0.001694 0.005551
# random-seed grass-regrowth-time 0.002200 0.005679
# initial-number-sheep sheep-gain-from-food -0.004731 0.011941
# initial-number-sheep sheep-reproduce -0.000608 0.011592
# initial-number-sheep initial-number-wolves 0.003147 0.025845
# initial-number-sheep wolf-gain-from-food 0.006957 0.036864
# initial-number-sheep wolf-reproduce -0.001234 0.009860
# initial-number-sheep grass-regrowth-time -0.001981 0.011006
# sheep-gain-from-food sheep-reproduce -0.005216 0.021868
# sheep-gain-from-food initial-number-wolves -0.006251 0.025596
# sheep-gain-from-food wolf-gain-from-food 0.005358 0.037821
# sheep-gain-from-food wolf-reproduce -0.004538 0.022405
# sheep-gain-from-food grass-regrowth-time -0.004673 0.022157
# sheep-reproduce initial-number-wolves -0.003051 0.014464
# sheep-reproduce wolf-gain-from-food 0.015132 0.046806
# sheep-reproduce wolf-reproduce -0.000506 0.012384
# sheep-reproduce grass-regrowth-time -0.000798 0.011668
# initial-number-wolves wolf-gain-from-food 0.008712 0.038750
# initial-number-wolves wolf-reproduce 0.010969 0.038841
# initial-number-wolves grass-regrowth-time 0.010856 0.033914
# wolf-gain-from-food wolf-reproduce 0.037870 0.239179
# wolf-gain-from-food grass-regrowth-time 0.179882 0.544965
# wolf-reproduce grass-regrowth-time 0.003219 0.006369

# %%
print(np.abs(Si_Sobol["S1"]))
Si_Sobol["S1"] = np.abs(Si_Sobol["S1"])
from matplotlib import pyplot
import numpy as np
S1_and_interactions_sobol = np.append(Si_Sobol["S1"],(1 - Si_Sobol["S1"].sum()))
problem['names'] = ['random-seed', u'initial-number-sheep', u'sheep-gain-from-food', u'sheep-reproduce', u'initial-number-wolves', u'wolf-gain-from-food', u'wolf-reproduce', u'grass-regrowth-time']
labels = np.append(problem['names'],'interactions')
print(problem['names'])
explode=(0.5, 0.5, 0.5, 0.5,0.5, 0.5, 0.5, 0.5,0.5)
pyplot.pie(S1_and_interactions_sobol,explode=explode,labels=labels, startangle=-30, rotatelabels=40)
pyplot.show()
# Out:
# [0.00147492 0.00178054 0.00692299 0.00101132 0.01056231 0.11620695
#  0.00136825 0.00038499]
# ['random-seed', u'initial-number-sheep', u'sheep-gain-from-food', u'sheep-reproduce', u'initial-number-wolves', u'wolf-gain-from-food', u'wolf-reproduce', u'grass-regrowth-time']

# %%
fig = pyplot.figure(figsize=[10, 10])
ax = fig.add_subplot(111)
plot = ax.pie(Si_Sobol["ST"], labels = labels[0:8], labeldistance=1.02, startangle=-40, rotatelabels=90)

# %%
from SALib.analyze import fast
from SALib.sample import fast_sampler
nl4py.deleteAllHeadlessWorkspaces()
param_values_fast = fast_sampler.sample(problem, 1000)
Y = np.array(runForParameters(param_values_fast))
Si_FAST = fast.analyze(problem, Y, print_to_console=True)
# Out:
# Parameter First Total
# random-seed 0.001059 0.463228
# initial-number-sheep 0.010898 0.460543
# sheep-gain-from-food 0.006270 0.411794
# sheep-reproduce 0.005258 0.542986
# initial-number-wolves 0.010222 0.526413
# wolf-gain-from-food 0.170540 0.894915
# wolf-reproduce 0.004710 0.531344
# grass-regrowth-time 0.005400 0.695958

# %%
S1_and_interactions_fast = np.append(np.array(Si_FAST["S1"]),(1 - np.array(Si_FAST["S1"]).sum()))

fig = pyplot.figure(figsize=[10, 10])
ax = fig.add_subplot(111)
plot = ax.pie(S1_and_interactions_fast, labeldistance=1.02, labels = labels, startangle=-40, rotatelabels=90)

# %%
fig = pyplot.figure(figsize=[10, 10])
ax = fig.add_subplot(111)
plot = ax.pie(Si_FAST["ST"], labels = labels[0:8], labeldistance=1.02, startangle=-40, rotatelabels=90)

# %%
# Out:
# 8
